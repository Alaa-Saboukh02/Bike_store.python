# %% [markdown]
# # PYTHON DATA ANALYSIS

# %% [markdown]
# ## Outline
# - Data Analysis Steps
# - Full Data Analysis Case-study
#     - BikeStores Analysis

# %% [markdown]
# # Full Data Analysis Case-study (BikeStores Analysis)

# %% [markdown]
# ### 1] Libraries & Data Importing

# %% [markdown]
# ##### Import libraries and read in the BikeStores csv file

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
Bike_store = pd.read_csv('C:/Users/PC/Downloads/BikeStores.csv')

# %%
Bike_store
# Out:
#       order_id            customers        city state  order_date  \
# 0            1  Johnathan Velazquez  Pleasanton    CA    1/1/2016
# 1            1  Johnathan Velazquez  Pleasanton    CA    1/1/2016
# 2            1  Johnathan Velazquez  Pleasanton    CA    1/1/2016
# 3            1  Johnathan Velazquez  Pleasanton    CA    1/1/2016
# 4            1  Johnathan Velazquez  Pleasanton    CA    1/1/2016
# ...        ...                  ...         ...   ...         ...
# 4717      1614      Dorthey Jackson     Houston    TX  28/11/2018
# 4718      1614      Dorthey Jackson     Houston    TX  28/11/2018
# 4719      1615         Sarita Parks      Forney    TX  28/12/2018
# 4720      1615         Sarita Parks      Forney    TX  28/12/2018
# 4721      1615         Sarita Parks      Forney    TX  28/12/2018
#
#       total_units  revenue                                    product_name  \
# 0               2  1199.98            Electra Townie Original 7D EQ - 2016
# ...

# %% [markdown]
# ### 2] Data Understanding (Asking Questions)

# %%
#1- read data
#2- print head and tail
#3- info about data
#4- describe data
#5- Check missing values
#6- if missing values in any column ---> handle
#7- unique values and value count for each column
#8- shape of data

# %%
#read data
Bike_store
# Out:
#       order_id            customers        city state  order_date  \
# 0            1  Johnathan Velazquez  Pleasanton    CA    1/1/2016
# 1            1  Johnathan Velazquez  Pleasanton    CA    1/1/2016
# 2            1  Johnathan Velazquez  Pleasanton    CA    1/1/2016
# 3            1  Johnathan Velazquez  Pleasanton    CA    1/1/2016
# 4            1  Johnathan Velazquez  Pleasanton    CA    1/1/2016
# ...        ...                  ...         ...   ...         ...
# 4717      1614      Dorthey Jackson     Houston    TX  28/11/2018
# 4718      1614      Dorthey Jackson     Houston    TX  28/11/2018
# 4719      1615         Sarita Parks      Forney    TX  28/12/2018
# 4720      1615         Sarita Parks      Forney    TX  28/12/2018
# 4721      1615         Sarita Parks      Forney    TX  28/12/2018
#
#       total_units  revenue                                    product_name  \
# 0               2  1199.98            Electra Townie Original 7D EQ - 2016
# ...

# %% [markdown]
# ##### Check the content of the DataFrame

# %%
# print head and tail
Bike_store.head()
# Out:
#    order_id            customers        city state order_date  total_units  \
# 0         1  Johnathan Velazquez  Pleasanton    CA   1/1/2016            2
# 1         1  Johnathan Velazquez  Pleasanton    CA   1/1/2016            1
# 2         1  Johnathan Velazquez  Pleasanton    CA   1/1/2016            2
# 3         1  Johnathan Velazquez  Pleasanton    CA   1/1/2016            1
# 4         1  Johnathan Velazquez  Pleasanton    CA   1/1/2016            2
#
#    revenue                                    product_name  \
# 0  1199.98            Electra Townie Original 7D EQ - 2016
# 1   599.99  Electra Townie Original 7D EQ - Women's - 2016
# 2  3098.00                          Surly Straggler - 2016
# 3  2899.99                        Trek Fuel EX 8 29 - 2016
# 4  3599.98           Trek Remedy 29 Carbon Frameset - 2016
#
#          category_name brand_name        store_name        sales_rep
# 0    Cruisers Bicycles    Electra  Santa Cruz Bikes  Mireya Copeland
# ...

# %%
Bike_store.tail()
# Out:
#       order_id        customers     city state  order_date  total_units  \
# 4717      1614  Dorthey Jackson  Houston    TX  28/11/2018            1
# 4718      1614  Dorthey Jackson  Houston    TX  28/11/2018            2
# 4719      1615     Sarita Parks   Forney    TX  28/12/2018            1
# 4720      1615     Sarita Parks   Forney    TX  28/12/2018            1
# 4721      1615     Sarita Parks   Forney    TX  28/12/2018            2
#
#       revenue                   product_name      category_name brand_name  \
# 4717  1499.00           Surly Krampus - 2018     Mountain Bikes      Surly
# 4718  4599.98       Trek Emonda ALR 6 - 2018         Road Bikes       Trek
# 4719   899.99  Electra Tiger Shark 3i - 2018  Cruisers Bicycles    Electra
# 4720  2499.99   Trek Domane SL 5 Disc - 2018         Road Bikes       Trek
# 4721  4599.98     Trek Verve+ Lowstep - 2018     Electric Bikes       Trek
#
#          store_name    sales_rep
# 4717  Rowlett Bikes  Kali Vargas
# ...

# %%
#info about data
Bike_store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4722 entries, 0 to 4721
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       4722 non-null   int64
#  1   customers      4722 non-null   object
#  2   city           4722 non-null   object
#  3   state          4722 non-null   object
#  4   order_date     4722 non-null   object
#  5   total_units    4722 non-null   int64
#  6   revenue        4722 non-null   float64
#  7   product_name   4722 non-null   object
#  8   category_name  4722 non-null   object
#  9   brand_name     4722 non-null   object
#  10  store_name     4722 non-null   object
#  11  sales_rep      4722 non-null   object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 442.8+ KB

# %%
#describe data
Bike_store.describe()
# Out:
#           order_id  total_units       revenue
# count  4722.000000  4722.000000   4722.000000
# mean    821.265354     1.498941   1816.812554
# std     465.152168     0.500052   2228.160984
# min       1.000000     1.000000     89.990000
# 25%     423.250000     1.000000    539.980000
# 50%     828.500000     1.000000    939.980000
# 75%    1226.000000     2.000000   1999.980000
# max    1615.000000     2.000000  23999.980000

# %%
# Check missing values
Bike_store.isna().sum()
# Out:
# order_id         0
# customers        0
# city             0
# state            0
# order_date       0
# total_units      0
# revenue          0
# product_name     0
# category_name    0
# brand_name       0
# store_name       0
# sales_rep        0
# dtype: int64

# %%
# unique values and value count for each column
#Bike_store['order_id'].unique()
Bike_store['order_id'].value_counts()
Bike_store['product_name'].value_counts()
# Out:
# product_name
# Electra Townie Original 21D - 2016                 193
# Electra Cruiser 1 (24-Inch) - 2016                 193
# Electra Townie Original 7D EQ - 2016               185
# Electra Girl's Hawaii 1 (16-inch) - 2015/2016      180
# Surly Ice Cream Truck Frameset - 2016              110
#                                                   ...
# Electra Tiger Shark 3i (20-inch) - Boys' - 2018      1
# Trek Precaliber 24 21-speed Girl's - 2018            1
# Electra Straight 8 1 (16-inch) - Boy's - 2018        1
# Trek Precaliber 20 6-speed Girl's - 2018             1
# Electra Superbolt 1 20" - 2018                       1
# Name: count, Length: 278, dtype: int64

# %% [markdown]
# ##### How many rows and columns are there?

# %%
# Rows, Columns
Bike_store.shape
# Out:
# (4722, 12)

# %% [markdown]
# ##### Check the data types

# %%
Bike_store.dtypes
# Out:
# order_id           int64
# customers         object
# city              object
# state             object
# order_date        object
# total_units        int64
# revenue          float64
# product_name      object
# category_name     object
# brand_name        object
# store_name        object
# sales_rep         object
# dtype: object

# %%
# Statistical Summary
print(Bike_store.describe(include='all'))
# Out:
#            order_id      customers       city state order_date  total_units  \
# count   4722.000000           4722       4722  4722       4722  4722.000000
# unique          NaN           1444        195     3        725          NaN
# top             NaN  Tameka Fisher  Scarsdale    NY   6/4/2018          NaN
# freq            NaN             13         61  3195         27          NaN
# mean     821.265354            NaN        NaN   NaN        NaN     1.498941
# std      465.152168            NaN        NaN   NaN        NaN     0.500052
# min        1.000000            NaN        NaN   NaN        NaN     1.000000
# 25%      423.250000            NaN        NaN   NaN        NaN     1.000000
# 50%      828.500000            NaN        NaN   NaN        NaN     1.000000
# 75%     1226.000000            NaN        NaN   NaN        NaN     2.000000
# max     1615.000000            NaN        NaN   NaN        NaN     2.000000
#
# ...

# %% [markdown]
# ### 3] Data Wrangling (Cleaning & Manipulation)

# %% [markdown]
# ##### Are there any missing / duplicated data?

# %%
print(Bike_store.isnull().sum())
# Out:
# order_id         0
# customers        0
# city             0
# state            0
# order_date       0
# total_units      0
# revenue          0
# product_name     0
# category_name    0
# brand_name       0
# store_name       0
# sales_rep        0
# dtype: int64

# %%
print(Bike_store.duplicated())
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4717    False
# 4718    False
# 4719    False
# 4720    False
# 4721    False
# Length: 4722, dtype: bool

# %%
print("Missing data per column:")
print(Bike_store.isnull().sum())

print("\nNumber of duplicated rows:")
print(Bike_store.duplicated().sum())
# Out:
# Missing data per column:
# order_id         0
# customers        0
# city             0
# state            0
# order_date       0
# total_units      0
# revenue          0
# product_name     0
# category_name    0
# brand_name       0
# store_name       0
# sales_rep        0
# dtype: int64
#
# Number of duplicated rows:
# 0

# %% [raw]
# #remove null
# ##Replace >>
# ## Numerical>> Mean , Categorical >> Mode
# data.fillna(....)
# data.dropna()

# %%
for column in Bike_store.columns:
    if Bike_store[column].dtype == 'object': 
        Bike_store[column].fillna(Bike_store[column].mode()[0], inplace=True)
    else:  
        Bike_store[column].fillna(Bike_store[column].mean(), inplace=True)

print(Bike_store)
# Out:
#       order_id            customers        city state  order_date  \
# 0            1  Johnathan Velazquez  Pleasanton    CA    1/1/2016
# 1            1  Johnathan Velazquez  Pleasanton    CA    1/1/2016
# 2            1  Johnathan Velazquez  Pleasanton    CA    1/1/2016
# 3            1  Johnathan Velazquez  Pleasanton    CA    1/1/2016
# 4            1  Johnathan Velazquez  Pleasanton    CA    1/1/2016
# ...        ...                  ...         ...   ...         ...
# 4717      1614      Dorthey Jackson     Houston    TX  28/11/2018
# 4718      1614      Dorthey Jackson     Houston    TX  28/11/2018
# 4719      1615         Sarita Parks      Forney    TX  28/12/2018
# 4720      1615         Sarita Parks      Forney    TX  28/12/2018
# 4721      1615         Sarita Parks      Forney    TX  28/12/2018
#
#       total_units  revenue                                    product_name  \
# 0               2  1199.98            Electra Townie Original 7D EQ - 2016
# ...

# %%
Bike_store_cleaned = Bike_store.dropna()
print(Bike_store_cleaned)
# Out:
#       order_id            customers        city state  order_date  \
# 0            1  Johnathan Velazquez  Pleasanton    CA    1/1/2016
# 1            1  Johnathan Velazquez  Pleasanton    CA    1/1/2016
# 2            1  Johnathan Velazquez  Pleasanton    CA    1/1/2016
# 3            1  Johnathan Velazquez  Pleasanton    CA    1/1/2016
# 4            1  Johnathan Velazquez  Pleasanton    CA    1/1/2016
# ...        ...                  ...         ...   ...         ...
# 4717      1614      Dorthey Jackson     Houston    TX  28/11/2018
# 4718      1614      Dorthey Jackson     Houston    TX  28/11/2018
# 4719      1615         Sarita Parks      Forney    TX  28/12/2018
# 4720      1615         Sarita Parks      Forney    TX  28/12/2018
# 4721      1615         Sarita Parks      Forney    TX  28/12/2018
#
#       total_units  revenue                                    product_name  \
# 0               2  1199.98            Electra Townie Original 7D EQ - 2016
# ...

# %%
#Sort Values
Bike_store_sorted = Bike_store.sort_values(by='order_date')
print(Bike_store_sorted)
# Out:
#       order_id            customers        city state order_date  total_units  \
# 0            1  Johnathan Velazquez  Pleasanton    CA   1/1/2016            2
# 1            1  Johnathan Velazquez  Pleasanton    CA   1/1/2016            1
# 2            1  Johnathan Velazquez  Pleasanton    CA   1/1/2016            2
# 3            1  Johnathan Velazquez  Pleasanton    CA   1/1/2016            1
# 4            1  Johnathan Velazquez  Pleasanton    CA   1/1/2016            2
# ...        ...                  ...         ...   ...        ...          ...
# 1189       427      Douglass Little      Duarte    CA   9/9/2016            2
# 1192       428            Bee Baker   Liverpool    NY   9/9/2016            2
# 1188       427      Douglass Little      Duarte    CA   9/9/2016            2
# 1190       427      Douglass Little      Duarte    CA   9/9/2016            2
# 1191       428            Bee Baker   Liverpool    NY   9/9/2016            1
#
# ...

# %%
Bike_store_sorted = Bike_store.sort_values(by=['revenue', 'order_id'], ascending=[True, False])
print(Bike_store_sorted)
# Out:
#       order_id        customers            city state  order_date  \
# 4260      1462   Louise Flowers           Depew    NY   22/3/2018
# 4186      1439     Jerlene Rios       Plainview    NY   15/3/2018
# 4147      1425   Lavina Dejesus        Newburgh    NY    7/3/2018
# 4288      1472     Thalia Horne      Amityville    NY   29/3/2018
# 3622      1252  Ollie Zimmerman         Anaheim    CA  18/11/2017
# ...        ...              ...             ...   ...         ...
# 2227       787     Collene Knox  Corpus Christi    TX   18/3/2017
# 1888       672      Delmar Wise        Lockport    NY   26/1/2017
# 4389      1506      Abby Gamble      Amityville    NY    8/4/2018
# 4498      1541   Pamelia Newman          Monroe    NY   16/4/2018
# 3977      1364     Shena Carter    Howard Beach    NY   25/1/2018
#
#       total_units   revenue                            product_name  \
# 4260            1     89.99  Strider Classic 12 Balance Bike - 2018
# ...

# %%
#Add Column
Bike_store['Total revenue'] = Bike_store['revenue'] + Bike_store['total_units']

# %%
Bike_store
# Out:
#       order_id            customers        city state  order_date  \
# 0            1  Johnathan Velazquez  Pleasanton    CA    1/1/2016
# 1            1  Johnathan Velazquez  Pleasanton    CA    1/1/2016
# 2            1  Johnathan Velazquez  Pleasanton    CA    1/1/2016
# 3            1  Johnathan Velazquez  Pleasanton    CA    1/1/2016
# 4            1  Johnathan Velazquez  Pleasanton    CA    1/1/2016
# ...        ...                  ...         ...   ...         ...
# 4717      1614      Dorthey Jackson     Houston    TX  28/11/2018
# 4718      1614      Dorthey Jackson     Houston    TX  28/11/2018
# 4719      1615         Sarita Parks      Forney    TX  28/12/2018
# 4720      1615         Sarita Parks      Forney    TX  28/12/2018
# 4721      1615         Sarita Parks      Forney    TX  28/12/2018
#
#       total_units  revenue                                    product_name  \
# 0               2  1199.98            Electra Townie Original 7D EQ - 2016
# ...

# %% [markdown]
# ##### Double-check for the columns names and update any of them if needed

# %%
#Rename Columns
Bike_store.columns = Bike_store.columns.str.upper()#Capitalize column names
print(Bike_store)
# Out:
#       ORDER_ID            CUSTOMERS        CITY STATE  ORDER_DATE  \
# 0            1  Johnathan Velazquez  Pleasanton    CA    1/1/2016
# 1            1  Johnathan Velazquez  Pleasanton    CA    1/1/2016
# 2            1  Johnathan Velazquez  Pleasanton    CA    1/1/2016
# 3            1  Johnathan Velazquez  Pleasanton    CA    1/1/2016
# 4            1  Johnathan Velazquez  Pleasanton    CA    1/1/2016
# ...        ...                  ...         ...   ...         ...
# 4717      1614      Dorthey Jackson     Houston    TX  28/11/2018
# 4718      1614      Dorthey Jackson     Houston    TX  28/11/2018
# 4719      1615         Sarita Parks      Forney    TX  28/12/2018
# 4720      1615         Sarita Parks      Forney    TX  28/12/2018
# 4721      1615         Sarita Parks      Forney    TX  28/12/2018
#
#       TOTAL_UNITS  REVENUE                                    PRODUCT_NAME  \
# 0               2  1199.98            Electra Townie Original 7D EQ - 2016
# ...

# %% [markdown]
# ### 4] Data Analysis & Visualization (EDA & Statistical Analysis)
# #### Exploratory Data Analysis

# %% [markdown]
# ##### What is the average Revenue?

# %%
manual_average = sum(Bike_store['REVENUE']) / len(Bike_store['REVENUE'])
print(manual_average)
# Out:
# 1816.8125540027095

# %% [markdown]
# ##### What were the highest and lowest Revenue?

# %%
highest_age = Bike_store['REVENUE'].max()
lowest_age = Bike_store['REVENUE'].min()

print(f"Highest revenue: {highest_age}")
print(f"Lowest revenue: {lowest_age}")
# Out:
# Highest revenue: 23999.98
# Lowest revenue: 89.99

# %% [markdown]
# ##### How many orders have 'Road Bikes'  as a category name ?

# %%
road_bikes_orders = Bike_store[Bike_store['CATEGORY_NAME'] == 'Road Bikes']

# %%
road_bikes_orders
# Out:
#       ORDER_ID        CUSTOMERS            CITY STATE  ORDER_DATE  \
# 1777       638    Verda Gilbert  East Northport    NY    4/1/2017
# 1778       638    Verda Gilbert  East Northport    NY    4/1/2017
# 1792       643     Lonna Franks         Ontario    CA    8/1/2017
# 1833       657      Mable Pratt       Coachella    CA   17/1/2017
# 1834       657      Mable Pratt       Coachella    CA   17/1/2017
# ...        ...              ...             ...   ...         ...
# 4705      1610    Linnie Branch     Plattsburgh    NY   25/8/2018
# 4708      1611     Lyndsey Bean        Fairport    NY    6/9/2018
# 4715      1613      Debra Burks    Orchard Park    NY  18/11/2018
# 4718      1614  Dorthey Jackson         Houston    TX  28/11/2018
# 4720      1615     Sarita Parks          Forney    TX  28/12/2018
#
#       TOTAL_UNITS  REVENUE                         PRODUCT_NAME CATEGORY_NAME  \
# 1777            2  1499.98           Surly Ogre Frameset - 2017    Road Bikes
# ...

# %%
num_road_bikes_orders = road_bikes_orders.shape[0]
print(num_road_bikes_orders)
# Out:
# 374

# %% [markdown]
# ##### Display the data which revenue greater than 10000

# %%
high_revenue_orders = Bike_store[Bike_store['REVENUE'] > 10000]
high_revenue_orders
# Out:
#       ORDER_ID          CUSTOMERS                    CITY STATE  ORDER_DATE  \
# 1798       645   Consuela Collier         North Tonawanda    NY    8/1/2017
# 1844       660        Ashlee Pena              Whitestone    NY   18/1/2017
# 1888       672        Delmar Wise                Lockport    NY   26/1/2017
# 1928       685      Ayanna Cherry               Smithtown    NY   31/1/2017
# 1953       692         Kasha Todd                Campbell    CA    5/2/2017
# 2029       717       Tereasa Bird              Ronkonkoma    NY   15/2/2017
# 2083       736      Klara Stanley                 Webster    NY   27/2/2017
# 2100       741     Thalia Dillard              San Angelo    TX   28/2/2017
# 2140       755    Kimberely Bowen                    Troy    NY    6/3/2017
# 2227       787       Collene Knox          Corpus Christi    TX   18/3/2017
# 2283       804     Letitia Franco        Saratoga Springs    NY   29/3/2017
# ...

# %% [markdown]
# ##### what is the total revenue for each Brand ?

# %%
total_revenue_by_brand =Bike_store.groupby('BRAND_NAME')['REVENUE'].sum().reset_index()
total_revenue_by_brand
# Out:
#      BRAND_NAME     REVENUE
# 0       Electra  1344143.79
# 1          Haro   207096.69
# 2        Heller   193798.71
# 3   Pure Cycles   166164.00
# 4       Ritchey    88498.82
# 5       Strider     4849.75
# 6  Sun Bicycles   381919.69
# 7         Surly  1063135.82
# 8          Trek  5129381.61

# %% [markdown]
# ##### what is the total revenue for each Category Name ?

# %%
total_revenue_by_Category =Bike_store.groupby('CATEGORY_NAME')['REVENUE'].sum().reset_index()
total_revenue_by_Category
# Out:
#          CATEGORY_NAME     REVENUE
# 0    Children Bicycles   327888.21
# 1     Comfort Bicycles   438506.87
# 2    Cruisers Bicycles  1109151.04
# 3  Cyclocross Bicycles   799874.60
# 4       Electric Bikes  1020236.85
# 5       Mountain Bikes  3030775.71
# 6           Road Bikes  1852555.60

# %% [markdown]
# ### you should ask 4 questions and answer it

# %% [raw]
#  Density graph using Kernel Density Estimation (KDE) and displays the mean and median of the data on the same graph.

# %%
ax = Bike_store['REVENUE'].plot(kind='density', figsize=(14,6)) # kde
ax.axvline(Bike_store['REVENUE'].mean(), color='red')
ax.axvline(Bike_store['REVENUE'].median(), color='green')

# %%
Create a Pie Chart that displays the distribution of data in the BRAND_NAME column.

# %%
Bike_store['CATEGORY_NAME'].value_counts().plot(kind='pie', figsize=(6,6))
# Out:
# <Axes: ylabel='count'>

# %%
ax = Bike_store['BRAND_NAME'].value_counts().plot(kind='bar', figsize=(14,6))
ax.set_ylabel('Number of Sales')
# Out:
# Text(0, 0.5, 'Number of Sales')

# %% [raw]
# REIALTON BETWEEN COLUMNS

# %%
numeric_columns = Bike_store.select_dtypes(include=['number'])

corr = numeric_columns.corr()

print(corr)
# Out:
#                ORDER_ID  TOTAL_UNITS   REVENUE  TOTAL REVENUE
# ORDER_ID       1.000000    -0.004685  0.112456       0.112448
# TOTAL_UNITS   -0.004685     1.000000  0.270860       0.271068
# REVENUE        0.112456     0.270860  1.000000       1.000000
# TOTAL REVENUE  0.112448     0.271068  1.000000       1.000000

# %% [markdown]
# # GOOD LUCK!
